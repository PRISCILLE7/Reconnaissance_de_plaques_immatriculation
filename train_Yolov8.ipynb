# %%
import os
os.chdir("/content/drive/MyDrive/projet_yolov8/projet_yolo")

# %%
ls
# Out:
# datasets/                          number-plate.yaml  __pycache__/
# Miniconda3-latest-Linux-x86_64.sh  preprocessing.py   train_Yolov8.ipynb

# %%
cat number-plate.yaml
# Out:
# names:
#   - number plate
#
# # Chemins de dossiers des images
# train: /content/drive/MyDrive/projet_yolov8/projet_yolo/datasets/images/train
# val: /content/drive/MyDrive/projet_yolov8/projet_yolo/datasets/images/valid
#
# # nombre de classes
# nc: 1  # Nombre de classes, ici 1 car nous ne détectons que des plaques d'immatriculation

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# Setup complete ✅ (12 CPUs, 83.5 GB RAM, 33.7/201.2 GB disk)

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=number-plate.yaml epochs=50
# Out:
# Ultralytics YOLOv8.2.81 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (NVIDIA A100-SXM4-40GB, 40514MiB)
# ...

# %%
# !zip -r /content/dossier.zip /content/drive/MyDrive/projet_yolov8
# Out:
#   adding: content/drive/MyDrive/projet_yolov8/ (stored 0%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/ (stored 0%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/train_Yolov8.ipynb (deflated 83%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/Miniconda3-latest-Linux-x86_64.sh (deflated 1%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/preprocessing.py (deflated 65%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/__pycache__/ (stored 0%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/__pycache__/preprocessing.cpython-311.pyc (deflated 35%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/datasets/ (stored 0%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/datasets/count_files.sh (deflated 60%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/datasets/labels/ (stored 0%)
#   adding: content/drive/MyDrive/projet_yolov8/projet_yolo/datasets/labels/train/ (stored 0%)
# ...
